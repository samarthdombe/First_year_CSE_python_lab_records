# %%
#Assignment 01
student_data = {
    "Student 01": {
        "Roll Number": 1272261126,
        "Name": "Samarth Dombe",
        "Branch": "Computer Science & Engineering",
        "Marks": (97, 93, 100),
    },
    "Student 02": {
        "Roll Number": 1272261125,
        "Name": "Advaet Chintakunta",
        "Branch": "Computer Science & Engineering",
        "Marks": (100, 95, 90),
    },
    "Student 03": {
        "Roll Number": 1272261127,
        "Name": "Rohit Manglani",
        "Branch": "Computer Science & Engineering",
        "Marks": (98, 95, 92),
    },
}

student_data["Student 04"] = {
    "Roll Number": 1272261050,
    "Name": "Maithili Ashtaputre",
    "Branch": "Information Technology",
    "Marks": (94, 98, 95),
}

del student_data["Student 02"]

student_data["Student 03"]["Branch"] = "Artificial Intelligence & Data Science"

student_data = list(student_data.keys())
for key in student_record_list:
    student = student_record_dict[key]
    print(f"Student No. : {key}")
    print(f"Name        : {student['Name']}")
    print(f"PRN         : {student['Roll Number']}")
    print(f"Branch      : {student['Branch']}")
    print(f"Marks       : {student['Marks']}")
    print("\n")
